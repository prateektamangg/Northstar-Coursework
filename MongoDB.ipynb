# %%
# !pip install "pymongo[srv]==3.12"
# Out:
# Requirement already satisfied: pymongo==3.12 in /usr/local/lib/python3.12/dist-packages (from pymongo[srv]==3.12) (3.12.0)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymongo[srv]==3.12) (1.16.0)

# %%
from pymongo import MongoClient

# %%
client = MongoClient(
"mongodb+srv://prateektamangg:Prateeklama132%40@cluster0.1405hmw.mongodb.net/?retryWrites=true&w=majority"
)

db = client["northstar"]

# %%
collection = db["customer_cases"]

# %%
document = {
    "customer_id": 1001,
    "order_id": 5001,
    "issue": "Late Delivery",
    "severity": "High"
}

collection.insert_one(document)

# %%
for record in collection.find():
    print(record)
# Out:
# {'_id': ObjectId('6a00dba0e6e3f9ea75dcacb3'), 'customer_id': 1001, 'order_id': 5001, 'issue': 'Late Delivery', 'severity': 'High'}

# %%
collection.update_one(
 {"order_id":5001},
 {"$set":{"status":"Resolved"}}
)

# %%
for record in collection.find():
    print(record)
# Out:
# {'_id': ObjectId('6a00dba0e6e3f9ea75dcacb3'), 'customer_id': 1001, 'order_id': 5001, 'issue': 'Late Delivery', 'severity': 'High', 'status': 'Resolved'}

# %%
collection.delete_one(
 {"order_id":5001}
)

# %%
pipeline = [
 {
   "$group":
   {
     "_id":"$severity",
     "total_cases":{"$sum":1}
   }
 }
]

results = collection.aggregate(pipeline)

for record in results:
    print(record)

# %%
collection.create_index("customer_id")
# Out:
# 'customer_id_1'

# %%
collection.find(
 {"severity":"High"}
).explain()
# Out:
# {'explainVersion': '1',
#  'queryPlanner': {'namespace': 'northstar.customer_cases',
#   'parsedQuery': {'severity': {'$eq': 'High'}},
#   'indexFilterSet': False,
#   'queryHash': '524E9400',
#   'planCacheShapeHash': '524E9400',
#   'planCacheKey': 'DC62D160',
#   'optimizationTimeMillis': 0,
#   'maxIndexedOrSolutionsReached': False,
#   'maxIndexedAndSolutionsReached': False,
#   'maxScansToExplodeReached': False,
#   'prunedSimilarIndexes': False,
#   'winningPlan': {'isCached': False,
#    'stage': 'COLLSCAN',
#    'filter': {'severity': {'$eq': 'High'}},
#    'direction': 'forward'},
#   'rejectedPlans': []},
#  'executionStats': {'executionSuccess': True,
#   'nReturned': 0,
#   'executionTimeMillis': 0,
#   'totalKeysExamined': 0,
#   'totalDocsExamined': 0,
#   'executionStages': {'isCached': False,
#    'stage': 'COLLSCAN',
#    'filter': {'severity': {'$eq': 'High'}},
#    'nReturned': 0,
#    'executionTimeMillisEstimate': 0,
#    'works': 1,
#    'advanced': 0,
#    'needTime': 0,
#    'needYield': 0,
#    'saveState': 0,
#    'restoreState': 0,
#    'isEOF': 1,
#    'direction': 'forward',
#    'docsExamined': 0},
#   'allPlansExecution': []},
#  'queryShapeHash': '060F3669C90201442B650BA16C6AB204B70722389F392D1B3720DE66CF4EF069',
#  'command': {'find': 'customer_cases',
#   'filter': {'severity': 'High'},
#   '$db': 'northstar'},
#  'serverInfo': {'host': 'ac-0brafmc-shard-00-01.1405hmw.mongodb.net',
#   'port': 27017,
#   'version': '8.0.23',
#   'gitVersion': 'ccf0d81588377542f00eeecf1b1ffbc095b1eeff'},
#  'serverParameters': {'internalQueryFacetBufferSizeBytes': 104857600,
#   'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#   'internalLookupStageIntermediateDocumentMaxSizeBytes': 16793600,
#   'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#   'internalQueryMaxBlockingSortMemoryUsageBytes': 33554432,
#   'internalQueryProhibitBlockingMergeOnMongoS': 0,
#   'internalQueryMaxAddToSetBytes': 104857600,
#   'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#   'internalQueryFrameworkControl': 'trySbeRestricted',
#   'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1},
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1778441660, 5),
#   'signature': {'hash': b'\xb9\x8cAk\x87\xaf\xed\xeaW\x17,\xf0\xc5\x1d\xd9\xe9#\x9bTo',
#    'keyId': 7594468761717964802}},
#  'operationTime': Timestamp(1778441660, 5)}
